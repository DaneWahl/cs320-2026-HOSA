# %%
print("\nMultiple assignments\n")
a, b, c = 5, 3.2, "Hello"
print("a= ", a)
print("b= ", b)
print("c= ", c)

x = y = z = "Python"
print("x = " + x)
print("y = " + y)
print("z = " + z)
# Out:
# Multiple assignments
#
# a=  5
# b=  3.2
# c=  Hello
# x = Python
# y = Python
# z = Python

# %%
first_message = "Hi!"
second_message = "How are you?"
full_message = f"{first_message} {second_message}"
print(full_message)
# Out:
# Hi! How are you?

# %%
print("\nFloat\n")
a= 2.2
b= 2
c= 0.1
print("a+b=", a+b)
print("a+c=", a+c)
print("a**b=", a**b)
# Out:
# Float
#
# a+b= 4.2
# a+c= 2.3000000000000003
# a**b= 4.840000000000001

# %%
print("How old are you?")
age = int(input())

if age < 22:
  print("You are to young to have a drink.")
elif age >= 80:
  print("Ok, you will get a free drink.")
else:
  print("Sure, enjoy your drink.")
# Out:
# How old are you?
# 80
# Ok, you will get a free drink.

# %%
import random

for i in range(1, random.randint(5,15)):
  print("this for loop has already run " + str(i) + " times.")
# Out:
# this for loop has already run 1 times.
# this for loop has already run 2 times.
# this for loop has already run 3 times.
# this for loop has already run 4 times.
# this for loop has already run 5 times.
# this for loop has already run 6 times.
# this for loop has already run 7 times.
# this for loop has already run 8 times.
# this for loop has already run 9 times.
# this for loop has already run 10 times.
# this for loop has already run 11 times.
# this for loop has already run 12 times.
# this for loop has already run 13 times.
# this for loop has already run 14 times.
